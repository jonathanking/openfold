# %%
import numpy as np
import sidechainnet as scn
from glob import glob
import os
import prody as pr
from sidechainnet.dataloaders.SCNProtein import SCNProtein
import tqdm.notebook as tqdm

# %%
TEST_DIR = "/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103"
VALID_DIR = "/net/pulsar/home/koes/jok120/openfold/data/validation/cameo/20220116"

USE_DIR = TEST_DIR

# %%
basenames = [os.path.splitext(os.path.basename(f))[0] for f in glob(os.path.join(USE_DIR, "fasta_dir", "*.fasta"))]
seq_lengths = [len(open(os.path.join(USE_DIR, "fasta_dir", f"{basename}.fasta")).readlines()[1].strip()) for basename in basenames]

# Now filter both lists to only include sequences with length <= 700
basenames = [basename for basename, seq_length in zip(basenames, seq_lengths) if seq_length <= 700]
seq_lengths = [seq_length for seq_length in seq_lengths if seq_length <= 700]
cif_paths = [os.path.join(USE_DIR, "data_dir", f"{basename[:4]}.cif") for basename in basenames]

# %%
# Use prody to parse the corresponding protein chains from the cif files within TEST_DIR/data_dir
# chains = [pr.parseMMCIF(os.path.join(TEST_DIR, "data_dir", f"{basename[:4]}.cif"), \
#                         chain=basename.split("_")[1]) \
#         for basename in basenames[:3]]

# def get_scnproteins_from_cif_dir(cif_dir):
#     """Return a list of sidechainnet proteins from the cif files in cif_dir."""
#     basenames = [os.path.splitext(os.path.basename(f))[0] for f in glob(os.path.join(cif_dir, "*.cif"))]
#     chains = [pr.parseMMCIF(os.path.join(cif_dir, f"{basename[:4]}.cif"), \
#                             chain=basename.split("_")[1]) \
#             for basename in basenames]
#     scnproteins = [scn.SCNPDBProtein.from_prody_chain(c) for c in chains]
#     return scnproteins

# %%
p = SCNProtein.from_cif(
    '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/data_dir/7e1b.cif',
    chain="A", 
    pdbid='7e1b', 
    include_resolution=False)

# %%
p.to_3Dmol()

# %%
print(p.seq)
"PDSADQA" in p.seq

# %% [markdown]
# # Identifying Gaps Via Prody

# %%
ag, header = pr.parseMMCIF(
    '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/data_dir/7e1b.cif',
    chain="A",
    header=True)

# %%
# Identify the missing residues using the header/_pdbx_unobs_or_zero_occ_residues field
missing_residues = ag.getHierView().getHeader().get('_pdbx_unobs_or_zero_occ_residues')

# %%
header.keys()

# %%
header['A'].sequence

# %%
"PDSADQA" in header['A'].sequence

# %%
pr.parseSTAR('/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/data_dir/7e1b.cif')

# %%
failed_valid = []
for cif_path, basename in tqdm.tqdm(zip(cif_paths, basenames), total=len(basenames)):
    chain = basename.split("_")[1]
    pnid = basename
    try:
        p = SCNProtein.from_cif(
                                cif_path, 
                                chid=chain, 
                                pdbid=pnid,
                                include_resolution=False)
                                # return_sequences=True)
    except ValueError:
        failed_valid.append(basename)

# %%
len(failed_valid), len(basenames), len(basenames)-len(failed_valid)

# %%
failed = []
for cif_path, basename in tqdm.tqdm(zip(cif_paths, basenames), total=len(basenames), smoothing=0):
    chain = basename.split("_")[1]
    pnid = basename
    try:
        p = SCNProtein.from_cif(
                                cif_path, 
                                chid=chain, 
                                pdbid=pnid,
                                include_resolution=False,)
                                # return_sequences=True)
    except ValueError:
        failed.append(basename)
# Out:
#   0%|          | 0/708 [00:00<?, ?it/s]

# %%
len(failed), len(basenames), len(basenames)-len(failed)
# Out:
# (583, 708, 125)

# %%
# Move the failed pkl, pdb, and png files out of the min data directory
for basename in failed:
    print(basename)
    for file in tqdm.tqdm_notebook(
        glob(os.path.join("/net/pulsar/home/koes/jok120/scnmin_evaltest230412/min", f"{basename}*")), total=len(failed)):
        # !mv $file {file.replace("/min/", "/had_gaps/")}

# %%
# Create new data directories for the validation and test sets
NEW_VAL_STRUCTURES_DIR = "/net/pulsar/home/koes/jok120/openfold/data/validation/cameo/20220116/minimized/data_dir"
NEW_VAL_ALIGNMENTS_DIR = "/net/pulsar/home/koes/jok120/openfold/data/validation/cameo/20220116/minimized/alignments"
OLD_VAL_STRUCTURES_DIR = "/net/pulsar/home/koes/jok120/openfold/data/validation/cameo/20220116/data_dir"
OLD_VAL_ALIGNMENTS_DIR = "/net/pulsar/home/koes/jok120/openfold/data/validation/cameo/20220116/alignments"

for d in [NEW_VAL_STRUCTURES_DIR, NEW_VAL_ALIGNMENTS_DIR]:
    if not os.path.exists(d):
        os.makedirs(d)

NEW_TEST_STRUCTURES_DIR = "/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/minimized/data_dir"
NEW_TEST_ALIGNMENTS_DIR = "/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/minimized/alignments"
OLD_TEST_STRUCTURES_DIR = "/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/data_dir"
OLD_TEST_ALIGNMENTS_DIR = "/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments"

for d in [NEW_TEST_STRUCTURES_DIR, NEW_TEST_ALIGNMENTS_DIR]:
    if not os.path.exists(d):
        os.makedirs(d)

# Copy the minimized pdb files to the new data directories, and copy the corresponding alignment files
min_valid_files = glob(os.path.join("/net/pulsar/home/koes/jok120/scnmin_eval230412/min", "*.pdb"))
min_test_files = glob(os.path.join("/net/pulsar/home/koes/jok120/scnmin_evaltest230412/min", "*.pdb"))

for f in tqdm.tqdm_notebook(min_valid_files, total=len(min_valid_files)):
    basename = os.path.splitext(os.path.basename(f))[0]
    print(basename)
    # !cp $f {os.path.join(NEW_VAL_STRUCTURES_DIR, basename+".pdb")}
    # !cp -R {os.path.join(OLD_VAL_ALIGNMENTS_DIR, basename)} {os.path.join(NEW_VAL_ALIGNMENTS_DIR, basename)}

for f in tqdm.tqdm_notebook(min_test_files, total=len(min_test_files)):
    basename = os.path.splitext(os.path.basename(f))[0]
    print(basename)
    # !cp $f {os.path.join(NEW_TEST_STRUCTURES_DIR, basename+".pdb")}
    # !cp -R {os.path.join(OLD_TEST_ALIGNMENTS_DIR, basename)} {os.path.join(NEW_TEST_ALIGNMENTS_DIR, basename)}
# Out:
#   0%|          | 0/23 [00:00<?, ?it/s]
# 7fbp_B
# 7kuw_A
# 7v5y_B
# 7bhy_A
# 7nf9_A
# 7ee3_C
# 7dfe_A
# 7puo_A
# 7atr_A
# 7dkk_A
# 7f7n_A
# 7mu9_A
# 7vnb_A
# 7prd_A
# 7ofn_A
# 7f0h_A
# 7l8n_A
# 7mwr_A
# 7mcc_A
# 7dmf_A
# 7dut_A
# 7wgk_A
# 7b7t_A
#   0%|          | 0/100 [00:00<?, ?it/s]
# 7e4j_A
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7e4j_A': No such file or directory
# 7lt7_A
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7lt7_A': No such file or directory
# 7mnv_B
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7mnv_B': No such file or directory
# 7mla_B
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7mla_B': No such file or directory
# 7mnk_A
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7mnk_A': No such file or directory
# 7eym_A
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7eym_A': No such file or directory
# 7lxk_A
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7lxk_A': No such file or directory
# 7eyl_A
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7eyl_A': No such file or directory
# 7lve_A
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7lve_A': No such file or directory
# 7lxs_A
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7lxs_A': No such file or directory
# 7mq4_A
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7mq4_A': No such file or directory
# 7lvf_A
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7lvf_A': No such file or directory
# 7opb_D
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7opb_D': No such file or directory
# 7osw_A
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7osw_A': No such file or directory
# 7n99_A
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7n99_A': No such file or directory
# 7om4_B
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7om4_B': No such file or directory
# 7pl4_A
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7pl4_A': No such file or directory
# 7p4n_A
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7p4n_A': No such file or directory
# 7pqw_A
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7pqw_A': No such file or directory
# 7ead_A
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7ead_A': No such file or directory
# 7fcc_A
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7fcc_A': No such file or directory
# 7pvm_A
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7pvm_A': No such file or directory
# 7l8n_A
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7l8n_A': No such file or directory
# 7p3i_B
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7p3i_B': No such file or directory
# 7n45_A
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7n45_A': No such file or directory
# 7q1t_A
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7q1t_A': No such file or directory
# 7mcc_A
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7mcc_A': No such file or directory
# 7ocj_G
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7ocj_G': No such file or directory
# 7oio_A
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7oio_A': No such file or directory
# 7qao_A
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7qao_A': No such file or directory
# 7qap_A
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7qap_A': No such file or directory
# 7puo_A
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7puo_A': No such file or directory
# 7mwr_A
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7mwr_A': No such file or directory
# 7qdw_A
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7qdw_A': No such file or directory
# 7qb0_A
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7qb0_A': No such file or directory
# 7ejg_C
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7ejg_C': No such file or directory
# 7ern_C
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7ern_C': No such file or directory
# 7qss_A
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7qss_A': No such file or directory
# 7qil_A
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7qil_A': No such file or directory
# 7r6p_A
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7r6p_A': No such file or directory
# 7r74_B
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7r74_B': No such file or directory
# 7rlk_D
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7rlk_D': No such file or directory
# 7skc_A
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7skc_A': No such file or directory
# 7snc_A
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7snc_A': No such file or directory
# 7r49_B
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7r49_B': No such file or directory
# 7k2z_A
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7k2z_A': No such file or directory
# 7t9x_A
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7t9x_A': No such file or directory
# 7sjl_A
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7sjl_A': No such file or directory
# 7sxb_A
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7sxb_A': No such file or directory
# 7tlf_G
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7tlf_G': No such file or directory
# 7t03_A
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7t03_A': No such file or directory
# 7tt9_A
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7tt9_A': No such file or directory
# 7u37_A
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7u37_A': No such file or directory
# 7tv9_C
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7tv9_C': No such file or directory
# 7upo_C
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7upo_C': No such file or directory
# 7upo_A
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7upo_A': No such file or directory
# 7v5f_A
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7v5f_A': No such file or directory
# 7rt7_D
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7rt7_D': No such file or directory
# 7vd7_B
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7vd7_B': No such file or directory
# 7q4l_A
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7q4l_A': No such file or directory
# 7vmf_A
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7vmf_A': No such file or directory
# 7vmh_C
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7vmh_C': No such file or directory
# 7t6a_A
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7t6a_A': No such file or directory
# 7uwg_C
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7uwg_C': No such file or directory
# 7vu5_A
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7vu5_A': No such file or directory
# 7vty_A
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7vty_A': No such file or directory
# 7vqw_A
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7vqw_A': No such file or directory
# 7we3_A
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7we3_A': No such file or directory
# 7wbn_A
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7wbn_A': No such file or directory
# 7vfc_A
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7vfc_A': No such file or directory
# 7wj0_A
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7wj0_A': No such file or directory
# 7acy_B
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7acy_B': No such file or directory
# 7x8c_B
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7x8c_B': No such file or directory
# 7xq5_B
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7xq5_B': No such file or directory
# 7y4n_A
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7y4n_A': No such file or directory
# 7y0i_A
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7y0i_A': No such file or directory
# 7y6b_A
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7y6b_A': No such file or directory
# 7y6c_A
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7y6c_A': No such file or directory
# 7ywq_A
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7ywq_A': No such file or directory
# 7xga_A
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7xga_A': No such file or directory
# 7zc8_A
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7zc8_A': No such file or directory
# 7zro_A
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7zro_A': No such file or directory
# 8ab1_E
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/8ab1_E': No such file or directory
# 8d08_D
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/8d08_D': No such file or directory
# 8doa_A
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/8doa_A': No such file or directory
# 7w61_A
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7w61_A': No such file or directory
# 7x7w_A
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7x7w_A': No such file or directory
# 8hjc_A
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/8hjc_A': No such file or directory
# 8dt0_A
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/8dt0_A': No such file or directory
# 7wgk_A
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7wgk_A': No such file or directory
# 7sci_A
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7sci_A': No such file or directory
# 7w7h_E
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7w7h_E': No such file or directory
# 8bnt_B
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/8bnt_B': No such file or directory
# 8ako_B
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/8ako_B': No such file or directory
# 8f09_A
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/8f09_A': No such file or directory
# 7w5c_A
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7w5c_A': No such file or directory
# 7spn_A
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7spn_A': No such file or directory
# 7w1i_A
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7w1i_A': No such file or directory
# 7ry6_A
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7ry6_A': No such file or directory
# 7vma_A
# cp: cannot stat '/net/pulsar/home/koes/jok120/openfold/data/test/cameo/20230103/alignments/7vma_A': No such file or directory

# %% [markdown]
# # Minimizing Data

# %%
# Loop through all of the cif paths, and for each one, extract the chain corresponding to the basename
# Load the chain into a sidechainnet protein object, and save it to a pickle file in UNMIN_PATH
UNMIN_PATH = "/net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin"
MIN_PATH = "/net/pulsar/home/koes/jok120/scnmin_evaltest230412/min"
os.makedirs(UNMIN_PATH, exist_ok=True)
os.makedirs(MIN_PATH, exist_ok=True)
for cif_path,basename in tqdm.tqdm(zip(cif_paths, basenames), total=len(basenames)):
    chain = basename.split("_")[1]
    pnid = basename
    try:
        p = SCNProtein.from_cif(cif_path, chid=chain, pdbid=pnid, include_resolution=False)
        
    except ValueError as e:
        if "The observed sequence" not in str(e):
            print(e)
        continue
    p.pickle(os.path.join(UNMIN_PATH, f"{pnid}.pkl"))
    print(f"Saved {pnid} to {os.path.join(UNMIN_PATH, f'{pnid}.pkl')}")
# Out:
#   0%|          | 0/708 [00:00<?, ?it/s]
# Saved 7p20_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7p20_A.pkl
# Saved 7lxs_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7lxs_A.pkl
# Saved 7fiw_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7fiw_B.pkl
# Saved 7dup_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7dup_A.pkl
# Saved 7x15_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7x15_A.pkl
# Saved 7erv_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7erv_A.pkl
# Saved 7lt7_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7lt7_A.pkl
# Saved 7elf_C to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7elf_C.pkl
# Saved 7vna_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7vna_A.pkl
# Saved 7nqd_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7nqd_B.pkl
# Saved 7znx_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7znx_A.pkl
# Saved 7rxe_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7rxe_A.pkl
# Saved 8b2m_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8b2m_A.pkl
# Saved 7e1b_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7e1b_A.pkl
# Saved 7rgs_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7rgs_A.pkl
# Saved 7pk5_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7pk5_A.pkl
# Saved 7ob6_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7ob6_A.pkl
# Saved 7fjs_L to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7fjs_L.pkl
# Saved 7qsx_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7qsx_A.pkl
# Saved 7ug9_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7ug9_A.pkl
# Saved 7tzg_D to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7tzg_D.pkl
# Saved 7ywg_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7ywg_B.pkl
# Saved 7wq5_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7wq5_A.pkl
# Saved 7n8u_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7n8u_A.pkl
# Saved 7tj1_D to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7tj1_D.pkl
# Saved 7uln_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7uln_A.pkl
# Saved 7usv_D to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7usv_D.pkl
# Saved 7e4j_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7e4j_A.pkl
# Saved 7vt4_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7vt4_A.pkl
# Saved 7vp3_C to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7vp3_C.pkl
# Saved 7vz6_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7vz6_A.pkl
# Saved 7yvt_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7yvt_B.pkl
# Saved 7w06_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7w06_A.pkl
# Saved 7t4z_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7t4z_A.pkl
# Saved 7x0r_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7x0r_B.pkl
# Saved 7w26_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7w26_A.pkl
# Saved 8dam_C to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8dam_C.pkl
# Saved 7qys_L to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7qys_L.pkl
# Saved 7s69_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7s69_A.pkl
# Saved 7lqn_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7lqn_A.pkl
# Saved 7qry_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7qry_B.pkl
# Saved 7ocj_G to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7ocj_G.pkl
# Saved 7pqw_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7pqw_A.pkl
# Saved 7uav_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7uav_A.pkl
# Saved 7vmh_C to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7vmh_C.pkl
# Saved 7txl_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7txl_A.pkl
# Saved 7u1b_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7u1b_A.pkl
# Saved 7s8t_J to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7s8t_J.pkl
# Saved 7zrn_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7zrn_A.pkl
# Saved 7qb0_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7qb0_A.pkl
# Saved 7r5y_E to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7r5y_E.pkl
# Saved 7w5c_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7w5c_A.pkl
# Saved 7x7w_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7x7w_A.pkl
# Saved 7wme_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7wme_A.pkl
# Saved 7t03_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7t03_A.pkl
# Saved 8dgg_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8dgg_A.pkl
# Saved 7bb8_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7bb8_A.pkl
# Saved 7qfj_D to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7qfj_D.pkl
# Saved 7wxz_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7wxz_A.pkl
# Saved 7v9f_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7v9f_A.pkl
# Saved 7etr_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7etr_A.pkl
# Saved 7txc_E to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7txc_E.pkl
# Saved 7yvz_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7yvz_A.pkl
# Saved 7q3r_F to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7q3r_F.pkl
# Saved 7r6r_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7r6r_A.pkl
# Saved 7qbz_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7qbz_A.pkl
# Saved 7w63_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7w63_B.pkl
# Saved 7kob_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7kob_A.pkl
# Saved 7eoz_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7eoz_A.pkl
# Saved 7pc7_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7pc7_B.pkl
# Saved 7opb_D to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7opb_D.pkl
# Saved 7e3q_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7e3q_A.pkl
# Saved 7snc_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7snc_A.pkl
# Saved 7w74_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7w74_A.pkl
# Saved 7zgf_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7zgf_A.pkl
# Saved 7s5c_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7s5c_A.pkl
# Saved 7tvc_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7tvc_B.pkl
# Saved 7f6j_C to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7f6j_C.pkl
# Saved 7upm_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7upm_A.pkl
# Saved 7xh0_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7xh0_A.pkl
# Saved 7qii_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7qii_B.pkl
# Saved 7pkw_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7pkw_A.pkl
# Saved 7v1k_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7v1k_A.pkl
# Saved 7qao_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7qao_A.pkl
# Saved 7xoi_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7xoi_A.pkl
# Saved 7va8_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7va8_A.pkl
# Saved 7ou3_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7ou3_A.pkl
# Saved 7twl_D to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7twl_D.pkl
# Saved 7xqv_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7xqv_B.pkl
# Saved 7q9e_C to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7q9e_C.pkl
# Saved 7pwe_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7pwe_A.pkl
# Saved 7lk4_D to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7lk4_D.pkl
# Saved 7ets_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7ets_B.pkl
# Saved 7r49_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7r49_B.pkl
# Saved 8bnt_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8bnt_B.pkl
# Saved 7vmt_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7vmt_B.pkl
# Saved 7od9_C to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7od9_C.pkl
# Saved 7m5w_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7m5w_A.pkl
# Saved 7z6b_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7z6b_A.pkl
# Saved 7wua_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7wua_A.pkl
# Saved 8b2p_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8b2p_A.pkl
# Saved 7lvf_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7lvf_A.pkl
# Saved 7pb4_I to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7pb4_I.pkl
# Saved 7vi8_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7vi8_B.pkl
# Saved 8dht_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8dht_A.pkl
# Saved 6zpp_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/6zpp_A.pkl
# Saved 7zmq_K to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7zmq_K.pkl
# Saved 7qce_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7qce_A.pkl
# Saved 7w5u_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7w5u_A.pkl
# Saved 7rej_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7rej_A.pkl
# Saved 7f4s_D to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7f4s_D.pkl
# Saved 7ebt_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7ebt_B.pkl
# Saved 8cso_C to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8cso_C.pkl
# Saved 7wbn_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7wbn_A.pkl
# Saved 7m1z_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7m1z_B.pkl
# Saved 7bgs_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7bgs_B.pkl
# Saved 7tv9_C to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7tv9_C.pkl
# Saved 7zc8_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7zc8_A.pkl
# Saved 7opy_F to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7opy_F.pkl
# Saved 8dte_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8dte_A.pkl
# Saved 7u2r_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7u2r_A.pkl
# Saved 7v4s_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7v4s_A.pkl
# Saved 7whf_G to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7whf_G.pkl
# Saved 7vbo_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7vbo_A.pkl
# Saved 7t1j_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7t1j_B.pkl
# Saved 7mkk_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7mkk_B.pkl
# Saved 7uqv_D to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7uqv_D.pkl
# Saved 8fbd_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8fbd_B.pkl
# Saved 7oj1_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7oj1_A.pkl
# Saved 7y9b_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7y9b_A.pkl
# Saved 7z5p_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7z5p_A.pkl
# Saved 7wfx_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7wfx_A.pkl
# Saved 7snj_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7snj_A.pkl
# Saved 7ona_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7ona_A.pkl
# Saved 7s03_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7s03_A.pkl
# Saved 7tbu_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7tbu_A.pkl
# Saved 7o9f_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7o9f_B.pkl
# Saved 7xgb_C to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7xgb_C.pkl
# Saved 7w61_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7w61_A.pkl
# Saved 8cu5_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8cu5_A.pkl
# Saved 7fdp_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7fdp_B.pkl
# Saved 8ds5_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8ds5_A.pkl
# Saved 7r24_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7r24_A.pkl
# Saved 7xga_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7xga_A.pkl
# Saved 7rlk_D to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7rlk_D.pkl
# Saved 8enb_D to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8enb_D.pkl
# Saved 7uby_C to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7uby_C.pkl
# Saved 8h6s_D to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8h6s_D.pkl
# Saved 7v2s_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7v2s_B.pkl
# Saved 7ohz_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7ohz_B.pkl
# Saved 7fav_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7fav_A.pkl
# Saved 7zmn_K to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7zmn_K.pkl
# Saved 8cxa_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8cxa_A.pkl
# Saved 7y50_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7y50_A.pkl
# Saved 8ew6_V to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8ew6_V.pkl
# Saved 8d89_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8d89_A.pkl
# Saved 7tol_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7tol_A.pkl
# Saved 7x8v_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7x8v_A.pkl
# Saved 7erp_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7erp_B.pkl
# Saved 8akp_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8akp_A.pkl
# Saved 7dki_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7dki_A.pkl
# Saved 7a67_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7a67_B.pkl
# Saved 7z2u_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7z2u_A.pkl
# Saved 7e0l_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7e0l_A.pkl
# Saved 7qpe_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7qpe_A.pkl
# Saved 7q51_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7q51_A.pkl
# Saved 7wg3_K to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7wg3_K.pkl
# Saved 7r1k_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7r1k_A.pkl
# Saved 7upo_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7upo_A.pkl
# Saved 7y79_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7y79_B.pkl
# Saved 7r0o_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7r0o_B.pkl
# Saved 7y78_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7y78_B.pkl
# Saved 7oju_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7oju_A.pkl
# Saved 7ntn_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7ntn_A.pkl
# Saved 7y55_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7y55_A.pkl
# Saved 7y6c_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7y6c_A.pkl
# Saved 8a4a_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8a4a_A.pkl
# Saved 7msk_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7msk_A.pkl
# Saved 7vqw_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7vqw_A.pkl
# Saved 7t7y_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7t7y_A.pkl
# Saved 7mo3_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7mo3_B.pkl
# Saved 7n40_C to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7n40_C.pkl
# Saved 7t8j_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7t8j_A.pkl
# Saved 7e0v_C to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7e0v_C.pkl
# Saved 7oxl_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7oxl_A.pkl
# Saved 7r74_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7r74_B.pkl
# Saved 8e8u_C to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8e8u_C.pkl
# Saved 8cwu_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8cwu_B.pkl
# Saved 7x0q_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7x0q_A.pkl
# Saved 7vrs_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7vrs_A.pkl
# Saved 7zj3_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7zj3_A.pkl
# Saved 7rup_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7rup_A.pkl
# Saved 7ym0_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7ym0_A.pkl
# Saved 7s2r_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7s2r_B.pkl
# Saved 7eqb_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7eqb_A.pkl
# Saved 7zk1_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7zk1_A.pkl
# Saved 7ezb_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7ezb_A.pkl
# Saved 7wrp_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7wrp_A.pkl
# Saved 7t7i_D to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7t7i_D.pkl
# Saved 7on9_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7on9_A.pkl
# Saved 7vnx_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7vnx_A.pkl
# Saved 7eyl_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7eyl_A.pkl
# Saved 7upq_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7upq_B.pkl
# Saved 7wjq_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7wjq_B.pkl
# Saved 7p3i_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7p3i_B.pkl
# Saved 7rpr_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7rpr_A.pkl
# Saved 8cwp_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8cwp_A.pkl
# Saved 7vmc_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7vmc_B.pkl
# Saved 8b02_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8b02_B.pkl
# Saved 7mhu_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7mhu_A.pkl
# Saved 7v6i_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7v6i_A.pkl
# Saved 7pno_D to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7pno_D.pkl
# Saved 7lve_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7lve_A.pkl
# Saved 8d4o_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8d4o_A.pkl
# Saved 7vt5_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7vt5_A.pkl
# Saved 7wj0_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7wj0_A.pkl
# Saved 7kpj_E to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7kpj_E.pkl
# Saved 7tvw_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7tvw_A.pkl
# Saved 7f08_N to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7f08_N.pkl
# Saved 7oq6_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7oq6_A.pkl
# Saved 7pab_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7pab_A.pkl
# Saved 7ko9_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7ko9_A.pkl
# Saved 8e1z_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8e1z_A.pkl
# Saved 8bfh_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8bfh_A.pkl
# Saved 7pp2_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7pp2_A.pkl
# Saved 7lh6_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7lh6_A.pkl
# Saved 7nuv_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7nuv_A.pkl
# Saved 7nde_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7nde_A.pkl
# Saved 7t1y_C to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7t1y_C.pkl
# Saved 7mla_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7mla_B.pkl
# Saved 7q4l_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7q4l_A.pkl
# Saved 8ctr_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8ctr_A.pkl
# Saved 7sz2_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7sz2_B.pkl
# Saved 7qs2_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7qs2_A.pkl
# Saved 7vfq_C to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7vfq_C.pkl
# Saved 7rcz_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7rcz_A.pkl
# Saved 7pgf_D to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7pgf_D.pkl
# Saved 7w89_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7w89_A.pkl
# Saved 7vf3_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7vf3_B.pkl
# Saved 7fev_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7fev_A.pkl
# Saved 7qqa_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7qqa_A.pkl
# Saved 8dko_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8dko_B.pkl
# Saved 7q4i_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7q4i_B.pkl
# Saved 7qsu_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7qsu_A.pkl
# Saved 7esg_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7esg_A.pkl
# Saved 7wew_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7wew_A.pkl
# Saved 8b8b_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8b8b_A.pkl
# Saved 7ry7_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7ry7_A.pkl
# Saved 7n7g_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7n7g_A.pkl
# Saved 7uss_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7uss_A.pkl
# Saved 7ymo_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7ymo_A.pkl
# Saved 7v40_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7v40_A.pkl
# Saved 7vrc_C to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7vrc_C.pkl
# Saved 7uxt_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7uxt_A.pkl
# Saved 7wgk_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7wgk_A.pkl
# Saved 7wrk_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7wrk_A.pkl
# Saved 7z27_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7z27_A.pkl
# Saved 8ajp_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8ajp_A.pkl
# Saved 7pvm_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7pvm_A.pkl
# Saved 7vru_C to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7vru_C.pkl
# Saved 7rkc_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7rkc_A.pkl
# Saved 7mo6_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7mo6_B.pkl
# Saved 7tt9_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7tt9_A.pkl
# Saved 8bd1_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8bd1_A.pkl
# Saved 8f09_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8f09_A.pkl
# Saved 7voh_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7voh_A.pkl
# Saved 7e3t_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7e3t_A.pkl
# Saved 7q83_D to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7q83_D.pkl
# Saved 7zgi_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7zgi_B.pkl
# Saved 8dt0_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8dt0_A.pkl
# Saved 7uwg_C to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7uwg_C.pkl
# Saved 7vrb_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7vrb_A.pkl
# Saved 7ead_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7ead_A.pkl
# Saved 7mq4_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7mq4_A.pkl
# Saved 7fgb_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7fgb_A.pkl
# Saved 7oj2_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7oj2_A.pkl
# Saved 8ako_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8ako_B.pkl
# Saved 7ox1_Z to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7ox1_Z.pkl
# Saved 7qdv_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7qdv_A.pkl
# Saved 7f5k_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7f5k_A.pkl
# Saved 7rt7_D to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7rt7_D.pkl
# Saved 8dys_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8dys_A.pkl
# Saved 7y4n_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7y4n_A.pkl
# Saved 7te3_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7te3_A.pkl
# Saved 7toc_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7toc_A.pkl
# Saved 7qss_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7qss_A.pkl
# Saved 7u37_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7u37_A.pkl
# Saved 7wnw_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7wnw_B.pkl
# Saved 7oyl_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7oyl_A.pkl
# Saved 7lx4_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7lx4_A.pkl
# Saved 7dri_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7dri_A.pkl
# Saved 7x4o_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7x4o_B.pkl
# Saved 7skh_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7skh_B.pkl
# Saved 7x8c_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7x8c_B.pkl
# Saved 7n45_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7n45_A.pkl
# Saved 7thn_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7thn_B.pkl
# Saved 7zgt_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7zgt_A.pkl
# Saved 8b7s_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8b7s_A.pkl
# Saved 7e8j_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7e8j_A.pkl
# Saved 7sxb_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7sxb_A.pkl
# Saved 7skj_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7skj_A.pkl
# Saved 7zmp_K to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7zmp_K.pkl
# Saved 7wf8_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7wf8_B.pkl
# Saved 7vr2_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7vr2_A.pkl
# Saved 7sjl_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7sjl_A.pkl
# Saved 7opt_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7opt_A.pkl
# Saved 7xjt_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7xjt_B.pkl
# Saved 7fia_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7fia_A.pkl
# Saved 7qjt_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7qjt_A.pkl
# Saved 7so5_H to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7so5_H.pkl
# Saved 7xif_D to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7xif_D.pkl
# Saved 7rmy_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7rmy_A.pkl
# Saved 8b73_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8b73_A.pkl
# Saved 7pc4_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7pc4_A.pkl
# Saved 8bfi_C to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8bfi_C.pkl
# Saved 7spy_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7spy_A.pkl
# Saved 7zva_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7zva_A.pkl
# Saved 7stz_C to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7stz_C.pkl
# Saved 7x4e_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7x4e_A.pkl
# Saved 7qy5_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7qy5_B.pkl
# Saved 7t12_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7t12_B.pkl
# Saved 7skc_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7skc_A.pkl
# Saved 7pgi_D to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7pgi_D.pkl
# Saved 7lgr_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7lgr_A.pkl
# Saved 7x0b_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7x0b_B.pkl
# Saved 7esh_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7esh_A.pkl
# Saved 8e8t_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8e8t_B.pkl
# Saved 7om4_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7om4_B.pkl
# Saved 7tgi_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7tgi_B.pkl
# Saved 7rpn_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7rpn_A.pkl
# Saved 7pqi_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7pqi_A.pkl
# Saved 8b5t_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8b5t_A.pkl
# Saved 7rdn_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7rdn_A.pkl
# Saved 7mj3_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7mj3_A.pkl
# Saved 7r08_E to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7r08_E.pkl
# Saved 7u5o_C to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7u5o_C.pkl
# Saved 7ebq_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7ebq_A.pkl
# Saved 7ywq_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7ywq_A.pkl
# Saved 8b26_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8b26_A.pkl
# Saved 7r3i_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7r3i_B.pkl
# Saved 7rgw_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7rgw_A.pkl
# Saved 7qs5_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7qs5_A.pkl
# Saved 7zhr_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7zhr_B.pkl
# Saved 7x77_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7x77_A.pkl
# Saved 7roa_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7roa_A.pkl
# Saved 7zmr_K to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7zmr_K.pkl
# Saved 7ta5_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7ta5_A.pkl
# Saved 7vu7_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7vu7_A.pkl
# Saved 7ulh_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7ulh_A.pkl
# Saved 7w3r_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7w3r_A.pkl
# Saved 7ovp_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7ovp_A.pkl
# Saved 7mnk_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7mnk_A.pkl
# Saved 7pb9_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7pb9_A.pkl
# Saved 7pxy_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7pxy_A.pkl
# Saved 7e4u_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7e4u_A.pkl
# Saved 8ejm_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8ejm_B.pkl
# Saved 7t2s_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7t2s_A.pkl
# Saved 8e83_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8e83_A.pkl
# Saved 7lxk_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7lxk_A.pkl
# Saved 8axp_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8axp_A.pkl
# Saved 8h4z_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8h4z_A.pkl
# Saved 8h2c_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8h2c_A.pkl
# Saved 7tdv_C to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7tdv_C.pkl
# Saved 7r0r_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7r0r_A.pkl
# Saved 7puo_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7puo_A.pkl
# Saved 7w8u_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7w8u_A.pkl
# Saved 8cuk_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8cuk_B.pkl
# Saved 7myv_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7myv_B.pkl
# Saved 7yxg_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7yxg_A.pkl
# Saved 7eym_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7eym_A.pkl
# Saved 7wf9_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7wf9_A.pkl
# Saved 7vu5_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7vu5_A.pkl
# Saved 7n3t_C to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7n3t_C.pkl
# Saved 7sao_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7sao_A.pkl
# Saved 7fau_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7fau_B.pkl
# Saved 7vwt_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7vwt_A.pkl
# Saved 7us3_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7us3_A.pkl
# Saved 7efs_D to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7efs_D.pkl
# Saved 7qjo_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7qjo_B.pkl
# Saved 8edk_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8edk_A.pkl
# Saved 7vrs_C to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7vrs_C.pkl
# Saved 7b8b_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7b8b_A.pkl
# Saved 7zht_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7zht_A.pkl
# Saved 7fgp_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7fgp_A.pkl
# Saved 7on7_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7on7_A.pkl
# Saved 7upv_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7upv_A.pkl
# Saved 7y3w_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7y3w_A.pkl
# Saved 7mcc_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7mcc_A.pkl
# Saved 7rps_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7rps_A.pkl
# Saved 7qu2_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7qu2_A.pkl
# Saved 7dz2_C to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7dz2_C.pkl
# Saved 7pcr_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7pcr_A.pkl
# Saved 7sua_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7sua_A.pkl
# Saved 8dfk_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8dfk_A.pkl
# Saved 7puj_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7puj_A.pkl
# Saved 7oio_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7oio_A.pkl
# Saved 7y0i_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7y0i_A.pkl
# Saved 7tvy_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7tvy_B.pkl
# Saved 7v8e_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7v8e_B.pkl
# Saved 8b5v_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8b5v_A.pkl
# Saved 7ta9_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7ta9_A.pkl
# Saved 7vd7_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7vd7_B.pkl
# Saved 7qbp_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7qbp_A.pkl
# Saved 8d47_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8d47_B.pkl
# Saved 8bgm_D to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8bgm_D.pkl
# Saved 7qap_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7qap_A.pkl
# Saved 7vgm_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7vgm_A.pkl
# Saved 7ruq_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7ruq_A.pkl
# Saved 8dvh_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8dvh_A.pkl
# Saved 7qil_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7qil_A.pkl
# Saved 7wkq_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7wkq_A.pkl
# Saved 7tef_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7tef_A.pkl
# Saved 7raw_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7raw_A.pkl
# Saved 7wki_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7wki_B.pkl
# Saved 8ehe_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8ehe_B.pkl
# Saved 7zro_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7zro_A.pkl
# Saved 7r3w_D to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7r3w_D.pkl
# Saved 7wf6_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7wf6_A.pkl
# Saved 7qbg_E to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7qbg_E.pkl
# Saved 7eqh_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7eqh_A.pkl
# Saved 7vil_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7vil_A.pkl
# Saved 8gr2_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8gr2_A.pkl
# Saved 7n0e_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7n0e_A.pkl
# Saved 7vkk_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7vkk_A.pkl
# Saved 7vrf_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7vrf_A.pkl
# Saved 7vma_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7vma_A.pkl
# Saved 7w1f_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7w1f_B.pkl
# Saved 7uv8_U to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7uv8_U.pkl
# Saved 7n6h_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7n6h_A.pkl
# Saved 7ugh_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7ugh_A.pkl
# Saved 7zcl_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7zcl_B.pkl
# Saved 7vfc_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7vfc_A.pkl
# Saved 7zr3_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7zr3_A.pkl
# Saved 7u5y_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7u5y_A.pkl
# Saved 7y6b_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7y6b_A.pkl
# Saved 7tif_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7tif_A.pkl
# Saved 7eso_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7eso_A.pkl
# Saved 7q6d_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7q6d_A.pkl
# Saved 7r5z_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7r5z_B.pkl
# Saved 8ewu_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8ewu_B.pkl
# Saved 7exx_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7exx_A.pkl
# Saved 7r3p_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7r3p_A.pkl
# Saved 7pc3_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7pc3_A.pkl
# Saved 7f15_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7f15_B.pkl
# Saved 7v5f_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7v5f_A.pkl
# Saved 7eqs_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7eqs_A.pkl
# Saved 7wwr_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7wwr_A.pkl
# Saved 7zty_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7zty_A.pkl
# Saved 7wjt_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7wjt_B.pkl
# Saved 7bll_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7bll_A.pkl
# Saved 7pcs_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7pcs_B.pkl
# Saved 7poi_C to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7poi_C.pkl
# Saved 7u0e_H to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7u0e_H.pkl
# Saved 8eh2_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8eh2_A.pkl
# Saved 7tni_C to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7tni_C.pkl
# Saved 7er0_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7er0_A.pkl
# Saved 7qau_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7qau_A.pkl
# Saved 7wa9_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7wa9_A.pkl
# Saved 7p4n_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7p4n_A.pkl
# Saved 8doa_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8doa_A.pkl
# Saved 7rpy_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7rpy_A.pkl
# Saved 7jt9_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7jt9_A.pkl
# Saved 7vp6_D to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7vp6_D.pkl
# Saved 7pc1_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7pc1_A.pkl
# Saved 7f6l_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7f6l_B.pkl
# Saved 7qjn_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7qjn_A.pkl
# Saved 7pzj_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7pzj_A.pkl
# Saved 7vu4_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7vu4_A.pkl
# Saved 7phw_E to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7phw_E.pkl
# Saved 7fax_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7fax_A.pkl
# Saved 8d08_D to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8d08_D.pkl
# Saved 8heh_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8heh_B.pkl
# Saved 7d66_C to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7d66_C.pkl
# Saved 7yrt_C to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7yrt_C.pkl
# Saved 7aal_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7aal_A.pkl
# Saved 7u20_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7u20_B.pkl
# Saved 7qvb_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7qvb_B.pkl
# Saved 7pl4_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7pl4_A.pkl
# Saved 7pw1_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7pw1_A.pkl
# Saved 7ed1_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7ed1_A.pkl
# Saved 7psg_C to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7psg_C.pkl
# Saved 7osw_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7osw_A.pkl
# Saved 7vw0_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7vw0_B.pkl
# Saved 7lqm_D to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7lqm_D.pkl
# Saved 8di0_C to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8di0_C.pkl
# Saved 8hjc_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8hjc_A.pkl
# Saved 7p4a_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7p4a_A.pkl
# Saved 7t84_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7t84_B.pkl
# Saved 7x0d_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7x0d_A.pkl
# Saved 7pc9_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7pc9_A.pkl
# Saved 7y39_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7y39_B.pkl
# Saved 7stt_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7stt_A.pkl
# Saved 7x0f_C to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7x0f_C.pkl
# Saved 7sbd_H to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7sbd_H.pkl
# Saved 7qdw_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7qdw_A.pkl
# Saved 7wcj_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7wcj_A.pkl
# Saved 7soo_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7soo_A.pkl
# Saved 7p4l_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7p4l_B.pkl
# Saved 7e04_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7e04_A.pkl
# Saved 7s83_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7s83_A.pkl
# Saved 7x1k_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7x1k_A.pkl
# Saved 7z79_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7z79_B.pkl
# Saved 7w5s_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7w5s_A.pkl
# Saved 7z06_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7z06_A.pkl
# Saved 7ctx_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7ctx_B.pkl
# Saved 7p0h_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7p0h_A.pkl
# Saved 7f3a_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7f3a_A.pkl
# Saved 7q05_E to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7q05_E.pkl
# Saved 7waw_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7waw_A.pkl
# Saved 7acy_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7acy_B.pkl
# Saved 7eus_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7eus_B.pkl
# Saved 7yta_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7yta_B.pkl
# Saved 7ffa_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7ffa_A.pkl
# Saved 7ekz_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7ekz_A.pkl
# Saved 7u5f_D to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7u5f_D.pkl
# Saved 7tsq_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7tsq_A.pkl
# Saved 7pl7_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7pl7_A.pkl
# Saved 7mhw_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7mhw_A.pkl
# Saved 7oa7_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7oa7_A.pkl
# Saved 7vud_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7vud_A.pkl
# Saved 7qre_D to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7qre_D.pkl
# Saved 7s8k_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7s8k_B.pkl
# Saved 7tec_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7tec_A.pkl
# Saved 7r20_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7r20_B.pkl
# Saved 7x0g_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7x0g_A.pkl
# Saved 7mo1_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7mo1_B.pkl
# Saved 8dk0_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8dk0_A.pkl
# Saved 7sl5_G to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7sl5_G.pkl
# Saved 7y8u_E to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7y8u_E.pkl
# Saved 7r09_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7r09_A.pkl
# Saved 7w1i_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7w1i_A.pkl
# Saved 8d1x_D to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8d1x_D.pkl
# Saved 8cxl_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8cxl_A.pkl
# Saved 7qiu_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7qiu_A.pkl
# Saved 7w19_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7w19_A.pkl
# Saved 8dcy_C to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8dcy_C.pkl
# Saved 7jiz_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7jiz_A.pkl
# Saved 7thh_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7thh_A.pkl
# Saved 7mni_C to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7mni_C.pkl
# Saved 7mny_D to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7mny_D.pkl
# Saved 8a59_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8a59_A.pkl
# Saved 7qsw_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7qsw_B.pkl
# Saved 7sfn_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7sfn_B.pkl
# Saved 7rfq_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7rfq_A.pkl
# Saved 7upo_C to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7upo_C.pkl
# Saved 8enb_C to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8enb_C.pkl
# Saved 7zw9_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7zw9_A.pkl
# Saved 7v9h_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7v9h_A.pkl
# Saved 7te2_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7te2_A.pkl
# Saved 7w52_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7w52_B.pkl
# Saved 7xq5_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7xq5_B.pkl
# Saved 7v8t_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7v8t_A.pkl
# Saved 7vsp_C to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7vsp_C.pkl
# Saved 7v67_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7v67_A.pkl
# Saved 7x8j_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7x8j_A.pkl
# Saved 7ewu_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7ewu_B.pkl
# Saved 7n40_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7n40_B.pkl
# Saved 7t9x_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7t9x_A.pkl
# Saved 7w6x_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7w6x_A.pkl
# Saved 7w0i_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7w0i_A.pkl
# Saved 7w16_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7w16_A.pkl
# Saved 7ya2_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7ya2_B.pkl
# Saved 7ztb_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7ztb_A.pkl
# Saved 7thw_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7thw_A.pkl
# Saved 7o4o_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7o4o_A.pkl
# Saved 7el8_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7el8_A.pkl
# Saved 7f4l_D to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7f4l_D.pkl
# Saved 7pcv_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7pcv_A.pkl
# Saved 7ula_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7ula_A.pkl
# Saved 8gtl_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8gtl_A.pkl
# Saved 7p23_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7p23_A.pkl
# Saved 7nmi_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7nmi_B.pkl
# Saved 7tlf_G to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7tlf_G.pkl
# Saved 7fh0_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7fh0_B.pkl
# Saved 7f0o_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7f0o_B.pkl
# Saved 7f84_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7f84_A.pkl
# Saved 7tdr_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7tdr_A.pkl
# Saved 7ehg_E to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7ehg_E.pkl
# Saved 7xhv_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7xhv_B.pkl
# Saved 7wwx_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7wwx_A.pkl
# Saved 7tkv_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7tkv_A.pkl
# Saved 7xc3_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7xc3_A.pkl
# Saved 7x2e_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7x2e_A.pkl
# Saved 7q6g_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7q6g_A.pkl
# Saved 7b0k_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7b0k_A.pkl
# Saved 7f5g_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7f5g_B.pkl
# Saved 7a67_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7a67_A.pkl
# Saved 7ouu_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7ouu_B.pkl
# Saved 7win_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7win_B.pkl
# Saved 7vjs_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7vjs_A.pkl
# Saved 8gxf_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8gxf_B.pkl
# Saved 7y3k_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7y3k_A.pkl
# Saved 7e52_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7e52_A.pkl
# Saved 8dgq_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8dgq_A.pkl
# Saved 7x5e_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7x5e_B.pkl
# Saved 7ong_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7ong_A.pkl
# Saved 7rgv_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7rgv_A.pkl
# Saved 7e5j_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7e5j_A.pkl
# Saved 7blf_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7blf_A.pkl
# Saved 8di1_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8di1_A.pkl
# Saved 8ab1_E to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8ab1_E.pkl
# Saved 8f8u_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8f8u_A.pkl
# Saved 8dkr_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8dkr_B.pkl
# Saved 7pc6_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7pc6_A.pkl
# Saved 7uw7_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7uw7_A.pkl
# Saved 8dkt_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8dkt_B.pkl
# Saved 8ag9_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8ag9_A.pkl
# Saved 8day_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8day_A.pkl
# Saved 8b55_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8b55_A.pkl
# Saved 7l8n_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7l8n_A.pkl
# Saved 8dt6_C to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8dt6_C.pkl
# Saved 7xkg_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7xkg_A.pkl
# Saved 7n29_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7n29_B.pkl
# Saved 7pln_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7pln_A.pkl
# Saved 7e8k_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7e8k_B.pkl
# Saved 7tmu_C to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7tmu_C.pkl
# Saved 7e4s_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7e4s_A.pkl
# Saved 7vtk_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7vtk_A.pkl
# Saved 7w5m_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7w5m_A.pkl
# Saved 7yp4_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7yp4_B.pkl
# Saved 7rw4_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7rw4_A.pkl
# Saved 7eqe_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7eqe_A.pkl
# Saved 7mnv_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7mnv_B.pkl
# Saved 7tlf_I to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7tlf_I.pkl
# Saved 7vq6_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7vq6_A.pkl
# Saved 7t5w_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7t5w_B.pkl
# Saved 7ejg_C to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7ejg_C.pkl
# Saved 7vty_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7vty_A.pkl
# Saved 7p56_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7p56_A.pkl
# Saved 8ep4_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8ep4_A.pkl
# Saved 7vqk_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7vqk_A.pkl
# Saved 7spn_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7spn_A.pkl
# Saved 7qwt_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7qwt_A.pkl
# Saved 7sub_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7sub_A.pkl
# Saved 7mku_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7mku_A.pkl
# Saved 7r9b_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7r9b_A.pkl
# Saved 7ri3_C to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7ri3_C.pkl
# Saved 7zhl_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7zhl_A.pkl
# Saved 7ycv_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7ycv_A.pkl
# Saved 7ry6_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7ry6_A.pkl
# Saved 7fac_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7fac_A.pkl
# Saved 7f9h_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7f9h_A.pkl
# Saved 7wrs_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7wrs_B.pkl
# Saved 7t6a_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7t6a_A.pkl
# Saved 7ovv_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7ovv_B.pkl
# Saved 7onc_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7onc_A.pkl
# Saved 7mwr_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7mwr_A.pkl
# Saved 7xtm_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7xtm_B.pkl
# Saved 7etr_C to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7etr_C.pkl
# Saved 7zou_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7zou_A.pkl
# Saved 8a28_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8a28_A.pkl
# Saved 7sci_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7sci_A.pkl
# Saved 8d7f_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8d7f_A.pkl
# Saved 7r6p_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7r6p_A.pkl
# Saved 7k2z_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7k2z_A.pkl
# Saved 7vmf_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7vmf_A.pkl
# Saved 7vno_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7vno_A.pkl
# Saved 7txp_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7txp_A.pkl
# Saved 7p22_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7p22_A.pkl
# Saved 7n99_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7n99_A.pkl
# Saved 7xce_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7xce_A.pkl
# Saved 7n3y_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7n3y_A.pkl
# Saved 7lsv_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7lsv_B.pkl
# Saved 7f2y_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7f2y_A.pkl
# Saved 7qsw_C to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7qsw_C.pkl
# Saved 7tzv_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7tzv_A.pkl
# Saved 7qfi_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7qfi_B.pkl
# Saved 7th2_C to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7th2_C.pkl
# Saved 7rbp_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7rbp_A.pkl
# Saved 7r63_C to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7r63_C.pkl
# Saved 7e1c_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7e1c_A.pkl
# Saved 7u04_H to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7u04_H.pkl
# Saved 7rqf_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7rqf_A.pkl
# Saved 7fcc_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7fcc_A.pkl
# Saved 7re5_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7re5_B.pkl
# Saved 7t1s_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7t1s_A.pkl
# Saved 7o0b_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7o0b_A.pkl
# Saved 7f0a_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7f0a_A.pkl
# Saved 7tb5_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7tb5_A.pkl
# Saved 7ezn_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7ezn_A.pkl
# Saved 8ahp_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8ahp_A.pkl
# Saved 7vyu_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7vyu_A.pkl
# Saved 7qcp_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7qcp_B.pkl
# Saved 7sgn_C to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7sgn_C.pkl
# Saved 7pup_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7pup_A.pkl
# Saved 7we3_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7we3_A.pkl
# Saved 7w7h_E to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7w7h_E.pkl
# Saved 7x9e_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7x9e_A.pkl
# Saved 8d03_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/8d03_A.pkl
# Saved 7vpu_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7vpu_A.pkl
# Saved 7um4_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7um4_A.pkl
# Saved 7z3s_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7z3s_A.pkl
# Saved 7w7a_G to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7w7a_G.pkl
# Saved 7tze_C to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7tze_C.pkl
# Saved 7li0_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7li0_A.pkl
# Saved 7egt_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7egt_B.pkl
# Saved 7ux0_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7ux0_A.pkl
# Saved 7saf_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7saf_B.pkl
# Saved 7pce_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7pce_A.pkl
# Saved 7wbc_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7wbc_A.pkl
# Saved 7xi4_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7xi4_B.pkl
# Saved 7q1t_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7q1t_A.pkl
# Saved 7prq_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7prq_B.pkl
# Saved 7tcr_C to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7tcr_C.pkl
# Saved 7w42_B to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7w42_B.pkl
# Saved 7ed6_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7ed6_A.pkl
# Saved 7ern_C to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/7ern_C.pkl
# Saved 6y0d_A to /net/pulsar/home/koes/jok120/scnmin_evaltest230412/unmin/6y0d_A.pkl

# %%
p = SCNProtein.from_pkl(os.path.join(UNMIN_PATH, "7lxs_A.pkl"))

# %%
p.to_3Dmol()

# %%
p.fastbuild(add_hydrogens=True, inplace=True)

# %%
p.minimize()
